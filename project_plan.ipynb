# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Phase 1 - Core simulation
# Build:
# - 2 Tanks
# - 1 pump
# - 2-3 valves
# - Level updates
# - Basic manual control
#
# Goal:
# - See liquid move from one tank to another
#
# ## Phase 2 - Automation logic
# Add:
# - Auto transfer mode
# - High/low alarms
# - Interlokcs
# - Safe stop conditions
#
# Goal:
# - System behaves like a control system and just animation
#
# ## Phase 3 - HMI
# Add:
# - Simple dashboard
# - Tank level indicators
# - Valve pump status
# - Mode selection
# - Alarm display
#
# Goal:
# - Make it intuitive and presentable
#
# ## Phase 4 - Engineering documentation
# Add:
# - Tag list
# - I/O list
# - Fucntional description
# - FAT procedure
# - System overview diagram
#
# Goal:
# - Make it look more like a real engineering work

# %% [markdown]
# ## Real-world components
# - Tank: volume balance
# - Pump: fixed flow if conditions are met
# - Valve: binary open/close
# - Sensor: direct measurement of simulated value
# - Alarm: thershold logic
# - Controller: rule-based logic
